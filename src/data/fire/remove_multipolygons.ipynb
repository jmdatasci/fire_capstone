# %%
import pandas as pd
df = pd.read_csv("fire_zips_original.csv", index_col = 0)

# %%
df
# Out:
#       FIRE_NAME  ALARM_DATE   CONT_DATE  CAUSE    GIS_ACRES  Shape_Length  \
# 0        NELSON  2020-06-18  2020-06-23   11.0   109.602280   3252.523280
# 1        NELSON  2020-06-18  2020-06-23   11.0   109.602280   3252.523280
# 2       AMORUSO  2020-06-01  2020-06-04    2.0   685.585022   9653.760308
# 3       AMORUSO  2020-06-01  2020-06-04    2.0   685.585022   9653.760308
# 4       FLEMING  2020-03-31  2020-04-01    9.0    12.931545   1577.155857
# ...         ...         ...         ...    ...          ...           ...
# 13763    COFFEE  2014-07-29  2014-10-30    1.0  6256.270996  27936.642775
# 13764    COFFEE  2014-07-29  2014-10-30    1.0  6256.270996  27936.642775
# 13765     HELLO  2012-08-05  2012-10-01    1.0   977.024963   8580.699931
# 13766      STAR  2008-06-21  2008-07-14    1.0   267.612793  15869.974532
# 13767     DOTTA  2021-06-30  2021-07-22   14.0   531.909973  12371.501646
#
#          Shape_Area                                           geometry  \
# ...

# %%
smaller_df = df.drop('geometry', axis=1)

# %%
smaller_df.to_csv('fire_zip_no_mp.csv')
