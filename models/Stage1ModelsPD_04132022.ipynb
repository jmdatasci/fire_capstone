# %% [markdown]
# ### **0. Import libraries**

# %%
import pandas as pd
from datetime import datetime
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
#from xgboost import XGBRegressor
from scipy.special import huber
import numpy as np
import seaborn as sns
from statsmodels.tools.tools import maybe_unwrap_results
from statsmodels.graphics.gofplots import ProbPlot
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
import joblib
import os
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.compose import TransformedTargetRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import HuberRegressor
import patsy
import statsmodels.formula.api as smf
from patsy import dmatrices
RANDOM_STATE = 2023
TEST_SIZE = 0.2
#pip install --pre --extra-index - this for extracting features

# %%
os.getcwd()
# Out:
# '/home/ec2-user/fire_capstone/models'

# %%
#path='/home/ec2-user/finalish_df_6.csv'
path='final_df_2.csv'

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0   ZCTA  year_month  ins_1_no_bin_raw  ins_2_add_acres_raw  \
# 0           0  89010      199101          0.014313             2.171619
# 1           1  89010      199102          0.003401             1.473353
# 2           2  89010      199103          0.000000             0.000000
# 3           3  89010      199104          0.024555             4.317860
# 4           4  89010      199105          0.000000             0.000000
#
#    ins_3_norms  ins_4_add_acres_norms  ins_5_norm_bins_acres  ins_6_bins_raw  \
# 0     2.095820               0.001013               0.011318       24.261588
# 1     0.499474               0.000688               0.007878       16.875655
# 2     0.000000               0.000000               0.000000        0.000000
# 3     3.633868               0.002025               0.024022       51.209927
# 4     0.000000               0.000000               0.000000        0.000000
#
#     zip_pm25  ...  percent_pop_male_age_under_5  total_population  \
# 0  12.450976  ...                           2.4             275.6
# 1  11.255854  ...                           2.4             275.6
# 2   7.130000  ...                           2.4             275.6
# 3   7.899268  ...                           2.4             275.6
# 4   7.004146  ...                           2.4             275.6
#
#    percent_bach_deg_grad_new  percent_high_school_grad_new  \
# 0                  14.272763                     56.603842
# 1                  14.272763                     56.603842
# 2                  14.272763                     56.603842
# 3                  14.272763                     56.603842
# 4                  14.272763                     56.603842
#
#    percent_pop_age_15to19_new  percent_pop_female_age_15to19_new  \
# 0                   13.526364                          14.514991
# 1                   13.526364                          14.514991
# 2                   13.526364                          14.514991
# 3                   13.526364                          14.514991
# 4                   13.526364                          14.514991
#
#    percent_pop_male_age_10to14_new  percent_pop_male_age_15to19_new  \
# 0                          3.99958                         8.781446
# 1                          3.99958                         8.781446
# 2                          3.99958                         8.781446
# 3                          3.99958                         8.781446
# 4                          3.99958                         8.781446
#
#    Patient_disease  total_cases
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3          Anxiety          1.0
# 4              NaN          NaN
#
# [5 rows x 35 columns]

# %%
#Understand the data
df.describe()
# Out:
#         Unnamed: 0           ZCTA     year_month  ins_1_no_bin_raw  \
# count  553240.0000  553240.000000  553240.000000     553240.000000
# mean   276619.5000   93655.422815  200456.457669          0.080887
# std    159706.7758    1823.777970     807.583415          0.181611
# min         0.0000   89010.000000  199101.000000          0.000000
# 25%    138309.7500   92257.000000  199801.000000          0.000890
# 50%    276619.5000   93650.000000  200501.000000          0.018688
# 75%    414929.2500   95379.000000  201112.000000          0.085257
# max    553239.0000   97635.000000  201812.000000         59.096422
#
#        ins_2_add_acres_raw    ins_3_norms  ins_4_add_acres_norms  \
# count        553240.000000  553239.000000          553239.000000
# mean            180.613992      12.624722               0.084838
# std             690.453570     469.818959               0.476344
# min               0.000000       0.000000               0.000000
# 25%               0.033358       0.129711               0.000015
# 50%               6.389348       2.746922               0.002971
# 75%             106.151686      12.571215               0.049465
# max          125873.289036  348158.983667             258.866251
#
#        ins_5_norm_bins_acres  ins_6_bins_raw       zip_pm25  ...  \
# count          553239.000000    5.532400e+05  546132.000000  ...
# mean                0.921031    1.960284e+03      10.196409  ...
# std                 5.281303    7.397733e+03       5.970980  ...
# min                 0.000000    0.000000e+00       0.000000  ...
# 25%                 0.000187    4.042036e-01       5.977500  ...
# 50%                 0.033216    7.147301e+01       8.778750  ...
# 75%                 0.550639    1.181334e+03      13.051206  ...
# max              2951.697056    1.391002e+06      88.450000  ...
#
#        percent_pop_male_age_5to9  percent_pop_male_age_under_5  \
# count              542613.000000                 542613.000000
# mean                    7.133073                      7.667055
# std                     3.929625                      4.545869
# min                     0.000000                      0.000000
# 25%                     5.000000                      5.000000
# 50%                     6.800000                      7.200000
# 75%                     8.600000                      9.400000
# max                    44.700000                     81.300000
#
#        total_population  percent_bach_deg_grad_new  \
# count     542613.000000              542613.000000
# mean       20877.780141                  25.170781
# std        20747.480137                  16.990797
# min            2.000000                   0.010000
# 25%         1694.800000                  12.180891
# 50%        15998.000000                  20.928719
# 75%        34617.400000                  35.001311
# max       109414.000000                  95.000000
#
#        percent_high_school_grad_new  percent_pop_age_15to19_new  \
# count                 542613.000000               542613.000000
# mean                      75.292884                    7.817499
# std                       17.366630                    5.081301
# min                        0.486379                    0.010000
# 25%                       68.894423                    5.360227
# 50%                       80.708626                    7.331364
# 75%                       87.473210                    9.302500
# max                       95.000000                   95.000000
#
#        percent_pop_female_age_15to19_new  percent_pop_male_age_10to14_new  \
# count                      542613.000000                    542613.000000
# mean                            7.434557                         6.963290
# std                             5.710286                         4.312972
# min                             0.010000                         0.010000
# 25%                             4.874479                         4.854490
# 50%                             6.643380                         6.659300
# 75%                             8.677616                         8.369120
# max                            95.000000                        95.000000
#
#        percent_pop_male_age_15to19_new   total_cases
# count                    542613.000000  90722.000000
# mean                          6.065578      1.029398
# std                           4.371618      0.172535
# min                           0.010000      1.000000
# 25%                           4.021747      1.000000
# 50%                           5.653644      1.000000
# 75%                           7.217545      1.000000
# max                          95.000000      4.000000
#
# [8 rows x 34 columns]

# %%
df.shape
# Out:
# (553240, 35)

# %%
#split yearmonth into year and month
df=df.assign(date=df.loc[:,"year_month"].astype("string").str[0:4].astype("Datetime64").dt.year, month=df.loc[:,"year_month"].astype("string").str[4:])

# %%
df.head()
# Out:
#    Unnamed: 0   ZCTA  year_month  ins_1_no_bin_raw  ins_2_add_acres_raw  \
# 0           0  89010      199101          0.014313             2.171619
# 1           1  89010      199102          0.003401             1.473353
# 2           2  89010      199103          0.000000             0.000000
# 3           3  89010      199104          0.024555             4.317860
# 4           4  89010      199105          0.000000             0.000000
#
#    ins_3_norms  ins_4_add_acres_norms  ins_5_norm_bins_acres  ins_6_bins_raw  \
# 0     2.095820               0.001013               0.011318       24.261588
# 1     0.499474               0.000688               0.007878       16.875655
# 2     0.000000               0.000000               0.000000        0.000000
# 3     3.633868               0.002025               0.024022       51.209927
# 4     0.000000               0.000000               0.000000        0.000000
#
#     zip_pm25  ...  percent_bach_deg_grad_new  percent_high_school_grad_new  \
# 0  12.450976  ...                  14.272763                     56.603842
# 1  11.255854  ...                  14.272763                     56.603842
# 2   7.130000  ...                  14.272763                     56.603842
# 3   7.899268  ...                  14.272763                     56.603842
# 4   7.004146  ...                  14.272763                     56.603842
#
#    percent_pop_age_15to19_new  percent_pop_female_age_15to19_new  \
# 0                   13.526364                          14.514991
# 1                   13.526364                          14.514991
# 2                   13.526364                          14.514991
# 3                   13.526364                          14.514991
# 4                   13.526364                          14.514991
#
#    percent_pop_male_age_10to14_new  percent_pop_male_age_15to19_new  \
# 0                          3.99958                         8.781446
# 1                          3.99958                         8.781446
# 2                          3.99958                         8.781446
# 3                          3.99958                         8.781446
# 4                          3.99958                         8.781446
#
#    Patient_disease  total_cases  date  month
# 0              NaN          NaN  1991     01
# 1              NaN          NaN  1991     02
# 2              NaN          NaN  1991     03
# 3          Anxiety          1.0  1991     04
# 4              NaN          NaN  1991     05
#
# [5 rows x 37 columns]

# %%
#drop irrelevant columns
df=df.query("date<2017")
df1=df.drop(['Unnamed: 0','date','elevation_difference','Patient_disease','total_cases'],axis=1)
#df1=df.drop(['Unnamed: 0','date','elevation_difference'],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513813 entries, 0 to 553215
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ZCTA                               513813 non-null  int64
#  1   year_month                         513813 non-null  int64
#  2   ins_1_no_bin_raw                   513813 non-null  float64
#  3   ins_2_add_acres_raw                513813 non-null  float64
#  4   ins_3_norms                        513812 non-null  float64
#  5   ins_4_add_acres_norms              513812 non-null  float64
#  6   ins_5_norm_bins_acres              513812 non-null  float64
#  7   ins_6_bins_raw                     513813 non-null  float64
#  8   zip_pm25                           507117 non-null  float64
#  9   zip_elevation                      510906 non-null  float64
#  10  zip_wspd                           513813 non-null  float64
#  11  treatment                          513813 non-null  int64
#  12  year                               513813 non-null  int64
#  13  households_count                   504060 non-null  float64
#  14  mean_income_per_household          504060 non-null  float64
#  15  median_income_per_household        504060 non-null  float64
#  16  percent_pop_age_10to14             504060 non-null  float64
#  17  percent_pop_age_5to9               504060 non-null  float64
#  18  percent_pop_age_under_5            504060 non-null  float64
#  19  percent_pop_female_age_10to14      504060 non-null  float64
#  20  percent_pop_female_age_5to9        504060 non-null  float64
#  21  percent_pop_female_age_under_5     504060 non-null  float64
#  22  percent_pop_male_age_5to9          504060 non-null  float64
#  23  percent_pop_male_age_under_5       504060 non-null  float64
#  24  total_population                   504060 non-null  float64
#  25  percent_bach_deg_grad_new          504060 non-null  float64
#  26  percent_high_school_grad_new       504060 non-null  float64
#  27  percent_pop_age_15to19_new         504060 non-null  float64
#  28  percent_pop_female_age_15to19_new  504060 non-null  float64
#  29  percent_pop_male_age_10to14_new    504060 non-null  float64
#  30  percent_pop_male_age_15to19_new    504060 non-null  float64
#  31  month                              513813 non-null  string
# dtypes: float64(27), int64(4), string(1)
# memory usage: 129.4 MB

# %%
#dfrows_with_nulls=df1.isnull().any(axis=1).sum()
#n=df1.isnull().any(axis=1)
#nan_count = df1.isna().sum(axis = 1)
#nan_count
#df1[n]
rows_with_nulls=df1.isna().sum(axis=0)
with_nulls=df1.isna().sum(axis=1)
print(rows_with_nulls)
print(with_nulls)
nrows_with_missing_values=(df1.isna().any(axis=1).sum())
print(nrows_with_missing_values)
print(df1.shape)
# Out:
# ZCTA                                    0
# year_month                              0
# ins_1_no_bin_raw                        0
# ins_2_add_acres_raw                     0
# ins_3_norms                             1
# ins_4_add_acres_norms                   1
# ins_5_norm_bins_acres                   1
# ins_6_bins_raw                          0
# zip_pm25                             6696
# zip_elevation                        2907
# zip_wspd                                0
# treatment                               0
# year                                    0
# households_count                     9753
# mean_income_per_household            9753
# median_income_per_household          9753
# percent_pop_age_10to14               9753
# percent_pop_age_5to9                 9753
# percent_pop_age_under_5              9753
# percent_pop_female_age_10to14        9753
# percent_pop_female_age_5to9          9753
# percent_pop_female_age_under_5       9753
# percent_pop_male_age_5to9            9753
# percent_pop_male_age_under_5         9753
# total_population                     9753
# percent_bach_deg_grad_new            9753
# percent_high_school_grad_new         9753
# percent_pop_age_15to19_new           9753
# percent_pop_female_age_15to19_new    9753
# percent_pop_male_age_10to14_new      9753
# percent_pop_male_age_15to19_new      9753
# month                                   0
# dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 553211    0
# 553212    0
# 553213    0
# 553214    0
# 553215    0
# Length: 513813, dtype: int64
# 13325
# (513813, 32)

# %%
#cols=['zip_pm25','zip_elevation','median_income_per_household','total_population','percent_pop_age_10to14', 'percent_pop_age_5to9','percent_pop_age_under_5','percent_bach_deg_grad_new','percent_high_school_grad_new', 
#       'percent_pop_age_15to19_new']
#for i in cols:
#    df1.loc[:,i]=df1.groupby('year_month')[i].apply(lambda x : x.interpolate(method = "linear", order = 1, limit_direction = "both"))

# %%
#drop all rows with null values
df1.dropna(inplace=True)
print(df1.shape)
# Out:
# (500488, 32)

# %%
#convert zipcode to string
df1.loc[:,'ZCTA']=df1.loc[:,'ZCTA'].astype('string')

# %%
#introduce year as string for onehot encoding in the model
df1.loc[:,'month1']=df1.loc[:,'month'].astype('int')
df1.loc[:,'years']=df1.loc[:,'year'].astype('string')

# %%
#df1.info()
#df1.loc[:,'year'].nunique()

# %%
#select instruments
cols=['year','ins_1_no_bin_raw','ins_2_add_acres_raw', 'ins_3_norms', 'ins_4_add_acres_norms','ins_5_norm_bins_acres','ins_6_bins_raw',]
df1a=df1.loc[:,cols]

# %%
#make year_month an index and sort values by year_month
df1.loc[:,"year_month"]=df1.loc[:,"year_month"].astype(int)
df1.loc[:,"year_month1"]=df1.loc[:,"year_month"].astype('int')
df1.sort_values(by=['year_month'],inplace=True)
df1.set_index('year_month', inplace=True)
#df1.loc[:,"year"]=df.loc[:,"year"].astype(float)

# %%
df1a.set_index("year").plot(
    figsize=(16,16),
    subplots=True,
    layout=(3,3),
    sharey=False,
    legend=False,
    title=['ins_1_no_bin_raw','ins_2_add_acres_raw', 'ins_3_norms', 'ins_4_add_acres_norms','ins_5_norm_dist_numerator','ins_6_sub_bins_raw'],
);

# %%
#corr_df=df1.corr().drop('ZCTA',axis=1).drop('ZCTA',axis=0)
corr_df=df1.corr()
corr_df.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /tmp/ipykernel_16132/4148240826.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr_df.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_18ef5_row0_col0, #T_18ef5_row1_col1, #T_18ef5_row1_col5, #T_18ef5_row2_col2, #T_18ef5_row3_col3, #T_18ef5_row3_col4, #T_18ef5_row4_col3, #T_18ef5_row4_col4, #T_18ef5_row5_col1, #T_18ef5_row5_col5, #T_18ef5_row6_col6, #T_18ef5_row7_col7, #T_18ef5_row8_col8, #T_18ef5_row9_col9, #T_18ef5_row10_col10, #T_18ef5_row10_col30, #T_18ef5_row11_col11, #T_18ef5_row12_col12, #T_18ef5_row13_col13, #T_18ef5_row14_col14, #T_18ef5_row15_col15, #T_18ef5_row16_col16, #T_18ef5_row17_col17, #T_18ef5_row18_col18, #T_18ef5_row19_col19, #T_18ef5_row20_col20, #T_18ef5_row21_col21, #T_18ef5_row22_col22, #T_18ef5_row23_col23, #T_18ef5_row24_col24, #T_18ef5_row25_col25, #T_18ef5_row26_col26, #T_18ef5_row27_col27, #T_18ef5_row28_col28, #T_18ef5_row29_col29, #T_18ef5_row30_col10, #T_18ef5_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col1, #T_18ef5_row0_col4, #T_18ef5_row0_col5, #T_18ef5_row0_col9, #T_18ef5_row16_col22, #T_18ef5_row16_col27, #T_18ef5_row22_col16, #T_18ef5_row26_col7, #T_18ef5_row26_col27 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_18ef5_row0_col2, #T_18ef5_row0_col13 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_18ef5_row0_col3, #T_18ef5_row8_col22, #T_18ef5_row16_col6, #T_18ef5_row21_col26, #T_18ef5_row28_col17 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_18ef5_row0_col6, #T_18ef5_row1_col7, #T_18ef5_row1_col22, #T_18ef5_row3_col10, #T_18ef5_row3_col11, #T_18ef5_row3_col30, #T_18ef5_row4_col10, #T_18ef5_row4_col11, #T_18ef5_row4_col30, #T_18ef5_row5_col7, #T_18ef5_row5_col22, #T_18ef5_row11_col13, #T_18ef5_row14_col7, #T_18ef5_row20_col25, #T_18ef5_row21_col7, #T_18ef5_row24_col10, #T_18ef5_row24_col30, #T_18ef5_row28_col20 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_18ef5_row0_col7, #T_18ef5_row2_col6, #T_18ef5_row2_col7, #T_18ef5_row3_col7, #T_18ef5_row4_col7, #T_18ef5_row8_col6, #T_18ef5_row15_col7, #T_18ef5_row19_col6, #T_18ef5_row29_col7, #T_18ef5_row29_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_18ef5_row0_col8, #T_18ef5_row8_col11, #T_18ef5_row17_col26, #T_18ef5_row23_col11, #T_18ef5_row26_col21, #T_18ef5_row29_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_18ef5_row0_col10, #T_18ef5_row0_col30, #T_18ef5_row7_col24, #T_18ef5_row17_col18 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_18ef5_row0_col11, #T_18ef5_row8_col23, #T_18ef5_row10_col11, #T_18ef5_row10_col23, #T_18ef5_row11_col8, #T_18ef5_row19_col7, #T_18ef5_row20_col26, #T_18ef5_row28_col6, #T_18ef5_row28_col18, #T_18ef5_row30_col11, #T_18ef5_row30_col23 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_18ef5_row0_col12, #T_18ef5_row1_col8, #T_18ef5_row2_col16, #T_18ef5_row2_col24, #T_18ef5_row15_col11, #T_18ef5_row22_col10, #T_18ef5_row22_col30, #T_18ef5_row27_col6, #T_18ef5_row28_col22, #T_18ef5_row29_col16, #T_18ef5_row29_col24 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_18ef5_row0_col14, #T_18ef5_row1_col14, #T_18ef5_row1_col21, #T_18ef5_row2_col14, #T_18ef5_row3_col13, #T_18ef5_row3_col14, #T_18ef5_row4_col13, #T_18ef5_row4_col14, #T_18ef5_row5_col14, #T_18ef5_row5_col21, #T_18ef5_row7_col25, #T_18ef5_row9_col21, #T_18ef5_row22_col19, #T_18ef5_row29_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col15, #T_18ef5_row1_col13, #T_18ef5_row1_col23, #T_18ef5_row3_col19, #T_18ef5_row4_col19, #T_18ef5_row5_col13, #T_18ef5_row5_col23, #T_18ef5_row6_col8, #T_18ef5_row7_col21, #T_18ef5_row7_col27, #T_18ef5_row9_col1, #T_18ef5_row9_col15, #T_18ef5_row15_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col16, #T_18ef5_row22_col13, #T_18ef5_row24_col11 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_18ef5_row0_col17, #T_18ef5_row1_col17, #T_18ef5_row2_col25, #T_18ef5_row4_col17, #T_18ef5_row5_col17, #T_18ef5_row7_col28, #T_18ef5_row13_col7, #T_18ef5_row20_col10, #T_18ef5_row20_col30, #T_18ef5_row22_col20, #T_18ef5_row26_col8, #T_18ef5_row27_col8, #T_18ef5_row29_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col18, #T_18ef5_row0_col20, #T_18ef5_row1_col26, #T_18ef5_row5_col26, #T_18ef5_row6_col20, #T_18ef5_row6_col29, #T_18ef5_row8_col18, #T_18ef5_row9_col18, #T_18ef5_row11_col25, #T_18ef5_row15_col30, #T_18ef5_row22_col17, #T_18ef5_row26_col24, #T_18ef5_row29_col28 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col19, #T_18ef5_row2_col23, #T_18ef5_row3_col21, #T_18ef5_row4_col21, #T_18ef5_row7_col14, #T_18ef5_row9_col14, #T_18ef5_row9_col19, #T_18ef5_row14_col8, #T_18ef5_row29_col12, #T_18ef5_row29_col23 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col21, #T_18ef5_row2_col17, #T_18ef5_row3_col17, #T_18ef5_row6_col26, #T_18ef5_row8_col9, #T_18ef5_row9_col17, #T_18ef5_row11_col21, #T_18ef5_row28_col8, #T_18ef5_row29_col17, #T_18ef5_row29_col25 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col22, #T_18ef5_row10_col22, #T_18ef5_row11_col12, #T_18ef5_row14_col6, #T_18ef5_row14_col22, #T_18ef5_row16_col11, #T_18ef5_row16_col25, #T_18ef5_row20_col7, #T_18ef5_row25_col22, #T_18ef5_row28_col7, #T_18ef5_row30_col22 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_18ef5_row0_col23, #T_18ef5_row2_col15, #T_18ef5_row2_col19, #T_18ef5_row6_col14, #T_18ef5_row6_col19, #T_18ef5_row7_col15, #T_18ef5_row8_col15, #T_18ef5_row19_col8, #T_18ef5_row19_col11, #T_18ef5_row20_col8, #T_18ef5_row23_col7, #T_18ef5_row29_col15, #T_18ef5_row29_col19 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col24, #T_18ef5_row2_col0, #T_18ef5_row3_col16, #T_18ef5_row4_col16, #T_18ef5_row8_col24, #T_18ef5_row9_col24, #T_18ef5_row13_col6, #T_18ef5_row16_col28, #T_18ef5_row19_col28, #T_18ef5_row25_col11, #T_18ef5_row27_col22 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_18ef5_row0_col25, #T_18ef5_row2_col28, #T_18ef5_row5_col29, #T_18ef5_row13_col14, #T_18ef5_row22_col28 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col26, #T_18ef5_row0_col27, #T_18ef5_row1_col27, #T_18ef5_row2_col27, #T_18ef5_row3_col27, #T_18ef5_row3_col28, #T_18ef5_row4_col27, #T_18ef5_row4_col28, #T_18ef5_row5_col27, #T_18ef5_row6_col24, #T_18ef5_row9_col25, #T_18ef5_row10_col15, #T_18ef5_row22_col24, #T_18ef5_row24_col22, #T_18ef5_row29_col27, #T_18ef5_row30_col5, #T_18ef5_row30_col15 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col28, #T_18ef5_row10_col14, #T_18ef5_row12_col0, #T_18ef5_row13_col17, #T_18ef5_row14_col13, #T_18ef5_row20_col13, #T_18ef5_row20_col24, #T_18ef5_row27_col13, #T_18ef5_row30_col14 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_18ef5_row0_col29, #T_18ef5_row4_col29, #T_18ef5_row10_col18, #T_18ef5_row10_col20, #T_18ef5_row10_col27, #T_18ef5_row14_col12, #T_18ef5_row17_col13, #T_18ef5_row30_col18, #T_18ef5_row30_col20, #T_18ef5_row30_col27 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_18ef5_row1_col0, #T_18ef5_row5_col0, #T_18ef5_row25_col15 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_18ef5_row1_col2, #T_18ef5_row5_col2, #T_18ef5_row7_col9, #T_18ef5_row11_col3, #T_18ef5_row11_col4, #T_18ef5_row12_col19, #T_18ef5_row17_col0, #T_18ef5_row21_col13, #T_18ef5_row22_col4, #T_18ef5_row23_col25, #T_18ef5_row23_col28, #T_18ef5_row24_col28 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_18ef5_row1_col3, #T_18ef5_row3_col1, #T_18ef5_row3_col5, #T_18ef5_row24_col23 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_18ef5_row1_col4, #T_18ef5_row4_col1, #T_18ef5_row5_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_18ef5_row1_col6, #T_18ef5_row1_col10, #T_18ef5_row1_col30, #T_18ef5_row5_col6, #T_18ef5_row5_col10, #T_18ef5_row5_col30, #T_18ef5_row9_col8, #T_18ef5_row18_col25, #T_18ef5_row21_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_18ef5_row1_col9, #T_18ef5_row5_col9, #T_18ef5_row7_col10, #T_18ef5_row7_col16, #T_18ef5_row7_col30, #T_18ef5_row22_col25, #T_18ef5_row27_col11 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_18ef5_row1_col11, #T_18ef5_row5_col11, #T_18ef5_

# %%
fig, ax = plt.subplots(figsize=(16, 10))
hmap=sns.heatmap(corr_df)

# %%
np.tril(np.ones(corr_df.shape)).astype(np.bool)[0:5,0:5]
df_lt = corr_df.where(np.tril(np.ones(corr_df.shape)).astype(np.bool))

fig, ax = plt.subplots(figsize=(16, 10))
hmap=sns.heatmap(df_lt,cmap="Spectral")
# Out:
# /tmp/ipykernel_16132/3172025710.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.tril(np.ones(corr_df.shape)).astype(np.bool)[0:5,0:5]
# /tmp/ipykernel_16132/3172025710.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_lt = corr_df.where(np.tril(np.ones(corr_df.shape)).astype(np.bool))

# %%
df1.loc[:,"zip_pm25"].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#drop all rows with null values
#df1.dropna(inplace=True)
print(df1.shape)
# Out:
# (500488, 34)

# %%
df1.sort_index(inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500488 entries, 199101 to 201612
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ZCTA                               500488 non-null  string
#  1   ins_1_no_bin_raw                   500488 non-null  float64
#  2   ins_2_add_acres_raw                500488 non-null  float64
#  3   ins_3_norms                        500488 non-null  float64
#  4   ins_4_add_acres_norms              500488 non-null  float64
#  5   ins_5_norm_bins_acres              500488 non-null  float64
#  6   ins_6_bins_raw                     500488 non-null  float64
#  7   zip_pm25                           500488 non-null  float64
#  8   zip_elevation                      500488 non-null  float64
#  9   zip_wspd                           500488 non-null  float64
#  10  treatment                          500488 non-null  int64
#  11  year                               500488 non-null  int64
#  12  households_count                   500488 non-null  float64
#  13  mean_income_per_household          500488 non-null  float64
#  14  median_income_per_household        500488 non-null  float64
#  15  percent_pop_age_10to14             500488 non-null  float64
#  16  percent_pop_age_5to9               500488 non-null  float64
#  17  percent_pop_age_under_5            500488 non-null  float64
#  18  percent_pop_female_age_10to14      500488 non-null  float64
#  19  percent_pop_female_age_5to9        500488 non-null  float64
#  20  percent_pop_female_age_under_5     500488 non-null  float64
#  21  percent_pop_male_age_5to9          500488 non-null  float64
#  22  percent_pop_male_age_under_5       500488 non-null  float64
#  23  total_population                   500488 non-null  float64
#  24  percent_bach_deg_grad_new          500488 non-null  float64
#  25  percent_high_school_grad_new       500488 non-null  float64
#  26  percent_pop_age_15to19_new         500488 non-null  float64
#  27  percent_pop_female_age_15to19_new  500488 non-null  float64
#  28  percent_pop_male_age_10to14_new    500488 non-null  float64
#  29  percent_pop_male_age_15to19_new    500488 non-null  float64
#  30  month                              500488 non-null  string
#  31  month1                             500488 non-null  int64
#  32  years                              500488 non-null  string
#  33  year_month1                        500488 non-null  int64
# dtypes: float64(27), int64(4), string(3)
# memory usage: 133.6 MB

# %% [markdown]
# ## Stage 1 Model

# %%
#identify the x and y variables/columns
instrument = "ins_2_add_acres_raw"

#replace any of the instruments in the xvar below to create a new xvar and run the function

xvar=[instrument, 'zip_elevation', 'zip_wspd', 'year', 'households_count',
       'mean_income_per_household', 'median_income_per_household',
       'percent_pop_age_10to14', 'percent_pop_age_5to9',
       'percent_pop_age_under_5', 'percent_pop_female_age_10to14',
       'percent_pop_female_age_5to9', 'percent_pop_female_age_under_5',
       'percent_pop_male_age_5to9', 'percent_pop_male_age_under_5',
       'total_population', 'percent_bach_deg_grad_new',
       'percent_high_school_grad_new', 'percent_pop_age_15to19_new',
       'percent_pop_female_age_15to19_new', 'percent_pop_male_age_10to14_new',
       'percent_pop_male_age_15to19_new', 'ZCTA','month']



#xvar1=['ins_1_no_bin_raw','zip_elevation','zip_wspd', 'year','mean_income_per_household','percent_pop_age_10to14', 'percent_pop_age_5to9','percent_pop_age_under_5','percent_bach_deg_grad_new', 
#       'percent_pop_age_15to19_new','month','ZCTA']

#xvar1=['ins_1_no_bin_raw','zip_elevation','zip_wspd', 'year','median_income_per_household','total_population','percent_pop_age_10to14', 'percent_pop_age_5to9','percent_pop_age_under_5','percent_bach_deg_grad_new','percent_high_school_grad_new', 
#       'percent_pop_age_15to19_new','interaction',]
#xvar1=['zip_pm25','ins_1_no_bin_raw','zip_elevation','zip_wspd', 'year','median_income_per_household','total_population','percent_pop_age_10to14', 'percent_pop_age_5to9','percent_pop_age_under_5','percent_bach_deg_grad_new','percent_high_school_grad_new', 
#       'percent_pop_age_15to19_new','month','ZCTA']

xvar1=['zip_pm25',instrument,'zip_elevation','zip_wspd', 'year','median_income_per_household','month','ZCTA']

yvar=['zip_pm25']


X=(df1.loc[:,xvar1])
y=(df1.loc[:,yvar])

# %%
# save the model to disk
#filename = 'Baseline_Regresison_model_04122023.sav'
#joblib.dump(lr, filename)

# %% [markdown]
# # Stage 1 Models

# %%
df2=df1.loc[:,xvar1]

# %%
df2.loc[:,'month']=df2.loc[:,'month'].astype(int)
df2.loc[:,'ZCTA']=df2.loc[:,'ZCTA'].astype(int)

# %%
#formula='zip_pm25 ~ ins_1_no_bin_raw + zip_elevation + zip_wspd + year + median_income_per_household + percent_pop_age_10to14 + percent_pop_age_5to9 + percent_pop_age_under_5 + percent_bach_deg_grad_new + percent_high_school_grad_new + percent_pop_age_15to19_new + month + C(ZCTA) + C(month)+ ins_1_no_bin_raw:C(month):C(ZCTA)'
formula=f'zip_pm25 ~ {instrument} + zip_elevation + year + median_income_per_household + C(ZCTA) + C(month)+ {instrument}:C(month):C(ZCTA)'
y, X = dmatrices(formula, data=df2, return_type='dataframe')

# %%
3+3
# Out:
# 6

# %%
mod=sm.OLS(y,X)

# %%
import mkl
mkl.set_num_threads(64)
# Out:
# 32

# %%
res=mod.fit()

# %%
print(res.summary())

# %%
prediction=res.predict(X)

# %%
with open(f'{instrument}.txt', 'w') as f:
    f.write(str(res.summary().as_text()))

# %%
plt.plot(df2.groupby('year_month').mean().index,df2.groupby('year_month').mean()['zip_pm25'])
plt.plot(df2.groupby('year_month').mean().index,prediction.groupby(prediction.index).mean())

# %%
import sys
sys.getsizeof(res)

# %%
sys.getsizeof(mod)

# %%
sys.getsizeof(2)
