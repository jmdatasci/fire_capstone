# %%
import pandas as pd
df = pd.read_csv("fires_clean_with_zipcodes.csv", index_col = 0)

# %%
# !ls
# Out:
# balenaEtcher-1.14.3.dmg           fires_clean_eda.ipynb
# fire_as_pandas.csv                fires_clean_with_zipcodes.csv
# fire_clean_no_mps.csv             fires_cleaning.ipynb
# fire_zcta_add.ipynb               fires_dropped.csv
# fire_zip_no_mp.csv                fires_dropped_eda.ipynb
# fire_zips.csv                     linuxmint-20.3-cinnamon-64bit.iso
# fire_zips_original.csv            remove_multipolygons.ipynb
# fires_clean.csv                   zcta_census.csv

# %%
df
# Out:
#        FIRE_NAME  ALARM_DATE   CONT_DATE  CAUSE     GIS_ACRES   Shape_Length  \
# Index
# 0         NELSON  2020-06-18  2020-06-23   11.0    109.602280    3252.523280
# 1        AMORUSO  2020-06-01  2020-06-04    2.0    685.585022    9653.760308
# 3        FLEMING  2020-03-31  2020-04-01    9.0     12.931545    1577.155857
# 4       MELANESE  2020-04-14  2020-04-19   18.0     10.315964    1035.787625
# 5            PFE  2020-07-05  2020-07-05   14.0     36.701931    2348.114043
# ...          ...         ...         ...    ...           ...            ...
# 19728    ERSKINE  2016-06-23  2016-06-30   14.0  48008.351562  151614.699966
# 19728    ERSKINE  2016-06-23  2016-06-30   14.0  48008.351562  151614.699966
# 19728    ERSKINE  2016-06-23  2016-06-30   14.0  48008.351562  151614.699966
# 19729      GREAT  2016-05-13  2016-05-14    4.0     10.494216    1460.354604
# 19730  HAVILAH 2  2016-08-27  2016-08-28   14.0    303.799591    6834.981888
#
# ...

# %%
smaller_df = df.drop('geometry', axis=1)

# %%
smaller_df.to_csv('fire_zipcodes_compressed.csv')
